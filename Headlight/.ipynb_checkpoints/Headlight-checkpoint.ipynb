# %%
import pandas as pd

# %%
file = "HDLT_Sports Shoes Take Home Assignment 2021.csv"

# %%
file_df = pd.read_csv(file)
file_df.head()
# Out:
#                           Campaign Name                   Ad Set Name  \
# 0  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 1  Prospecting -- Signups and Purchases        US_Interest_Basketball
# 2  Prospecting -- Signups and Purchases        US_Interest_Basketball
# 3  Prospecting -- Signups and Purchases        US_Interest_Basketball
# 4  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
#
#                          Ad Name         Day  Impressions  Results  \
# 0     HDLT_Test_Static_WhiteShoe  2020-12-06        34584     24.0
# 1  HDLT_Test_Animated_Basketball  2020-12-23        31495     23.0
# 2  HDLT_Test_Animated_Basketball  2020-12-25        32807     22.0
# 3  HDLT_Test_Animated_Basketball  2020-12-26        30201     23.0
# 4     HDLT_Test_Static_WhiteShoe  2020-12-07        31713     26.0
#
#    Amount Spent (USD)  Purchase  Signup  Link Clicks     Status reasons
# 0            575.2901      14.0    24.0        194.0             active
# 1            494.6203      14.0    23.0        187.0             active
# 2            405.1159       9.0    22.0        184.0             active
# 3            402.2864      14.0    23.0        179.0             active
# 4            572.4368      10.0    26.0        178.0  limited by budget

# %%
file_df.dtypes
# Out:
# Campaign Name          object
# Ad Set Name            object
# Ad Name                object
# Day                    object
# Impressions             int64
# Results               float64
# Amount Spent (USD)    float64
# Purchase              float64
# Signup                float64
# Link Clicks           float64
# Status reasons         object
# dtype: object

# %%
##Question 1

# %%
cost = file_df["Amount Spent (USD)"].sum()
clicks = file_df["Purchase"].sum()
cost_per_click = cost/clicks
cost_per_click
# Out:
# 34.140708527131785

# %%
##Question 2

# %%
file_df.groupby("Ad Set Name").sum()
# Out:
#                                     Impressions   Results  Amount Spent (USD)  \
# Ad Set Name
# ALL_Retargeting_Signup No Purchase         7157    6758.0            263.1170
# ALL_Retargeting_Site Visitors            260817  256792.0            270.9965
# US_Interest_Basketball                   287266     209.0           4384.5710
# US_Lookalike_RecentPurchases             399350     312.0           6277.1776
# WW_Interest_Cricket                        6191       4.0            462.9274
# WW_Lookalike_RecentPurchases             556830     520.0          10361.9675
#
#                                     Purchase  Signup  Link Clicks
# Ad Set Name
# ALL_Retargeting_Signup No Purchase       0.0     0.0         17.0
# ALL_Retargeting_Site Visitors            0.0     0.0         62.0
# US_Interest_Basketball                 135.0   209.0       1598.0
# US_Lookalike_RecentPurchases           203.0   312.0       2331.0
# WW_Interest_Cricket                      0.0     4.0         31.0
# WW_Lookalike_RecentPurchases           307.0   520.0       3704.0

# %%
USA = file_df[(file_df["Ad Set Name"] == "US_Interest_Basketball") | (file_df["Ad Set Name"] == "US_Lookalike_RecentPurchases")]
USA["Purchase"].sum()
# Out:
# 338.0

# %%
World_wide = file_df[(file_df["Ad Set Name"] == "WW_Lookalike_RecentPurchases") | (file_df["Ad Set Name"] == "WW_Interest_Cricket")]
World_wide["Purchase"].sum()
# Out:
# 307.0

# %%
##Question 3

# %%
file_df.sort_values(by=["Day"])
# Out:
#                             Campaign Name                         Ad Set Name  \
# 35   Prospecting -- Signups and Purchases        WW_Lookalike_RecentPurchases
# 107  Prospecting -- Signups and Purchases                 WW_Interest_Cricket
# 24   Prospecting -- Signups and Purchases        WW_Lookalike_RecentPurchases
# 146  Prospecting -- Signups and Purchases        WW_Lookalike_RecentPurchases
# 32   Prospecting -- Signups and Purchases        WW_Lookalike_RecentPurchases
# ..                                    ...                                 ...
# 38   Prospecting -- Signups and Purchases        WW_Lookalike_RecentPurchases
# 118                      Retargeting Test  ALL_Retargeting_Signup No Purchase
# 123  Prospecting -- Signups and Purchases        WW_Lookalike_RecentPurchases
# 72                       Retargeting Test       ALL_Retargeting_Site Visitors
# 87   Prospecting -- Signups and Purchases        WW_Lookalike_RecentPurchases
#
#                          Ad Name         Day  Impressions   Results  \
# 35    HDLT_Test_Static_WhiteShoe  2020-12-01        17553      15.0
# 107     HDLT_Test_Static_Cricket  2020-12-01         2162       1.0
# 24   HDLT_Test_Animated_ShoeSpin  2020-12-01        15456       9.0
# 146   HDLT_Test_Static_BlackShoe  2020-12-01          867       NaN
# 32   HDLT_Test_Animated_ShoeSpin  2020-12-02        17348      14.0
# ..                           ...         ...          ...       ...
# 38    HDLT_Test_Static_WhiteShoe  2020-12-31        10447      10.0
# 118               Retargeting Ad  2020-12-31         2808    2638.0
# 123   HDLT_Test_Static_BlackShoe  2020-12-31          563       NaN
# 72                Retargeting Ad  2020-12-31       119482  117888.0
# 87   HDLT_Test_Animated_ShoeSpin  2020-12-31         1561       1.0
#
#      Amount Spent (USD)  Purchase  Signup  Link Clicks  \
# 35             360.8472       9.0    15.0         87.0
# 107            199.5539       NaN     1.0         10.0
# 24             269.0864       7.0     9.0        134.0
# 146             16.0217       NaN     NaN          2.0
# 32             263.4513       7.0    14.0        101.0
# ..                  ...       ...     ...          ...
# 38             240.1350       5.0    10.0         82.0
# 118            112.4984       NaN     NaN          6.0
# 123             16.1053       NaN     NaN          6.0
# 72             118.3483       NaN     NaN         25.0
# 87              26.8740       1.0     1.0         17.0
#
#                          Status reasons
# 35   campaign paused; limited by budget
# 107                                  na
# 24   campaign paused; limited by budget
# 146                                indc
# 32                         status check
# ..                                  ...
# 38                               active
# 118                              active
# 123                        status check
# 72                               active
# 87                    limited by budget
#
# [160 rows x 11 columns]

# %%
file_df["Day"] = pd.to_datetime(file_df["Day"], format="%Y-%m-%d")
file_df.dtypes
# Out:
# Campaign Name                 object
# Ad Set Name                   object
# Ad Name                       object
# Day                   datetime64[ns]
# Impressions                    int64
# Results                      float64
# Amount Spent (USD)           float64
# Purchase                     float64
# Signup                       float64
# Link Clicks                  float64
# Status reasons                object
# dtype: object

# %%
from datetime import date, timedelta

# %%
seven_days = file_df.loc[(file_df["Day"] >="2020-12-01")
                        & (file_df["Day"] < "2020-12-08")]
seven_days.sort_values(by=["Day"])
# Out:
#                             Campaign Name                   Ad Set Name  \
# 24   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 35   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 146  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 107  Prospecting -- Signups and Purchases           WW_Interest_Cricket
# 141  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 136  Prospecting -- Signups and Purchases           WW_Interest_Cricket
# 12   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 32   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 134  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 21   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 29   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 102  Prospecting -- Signups and Purchases           WW_Interest_Cricket
# 11   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 34   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 138  Prospecting -- Signups and Purchases           WW_Interest_Cricket
# 125  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 36   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 156  Prospecting -- Signups and Purchases           WW_Interest_Cricket
# 6    Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 111  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 119  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 57   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 147  Prospecting -- Signups and Purchases           WW_Interest_Cricket
# 0    Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 61   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 4    Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 129  Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 157  Prospecting -- Signups and Purchases           WW_Interest_Cricket
#
#                          Ad Name        Day  Impressions  Results  \
# 24   HDLT_Test_Animated_ShoeSpin 2020-12-01        15456      9.0
# 35    HDLT_Test_Static_WhiteShoe 2020-12-01        17553     15.0
# 146   HDLT_Test_Static_BlackShoe 2020-12-01          867      NaN
# 107     HDLT_Test_Static_Cricket 2020-12-01         2162      1.0
# 141   HDLT_Test_Static_BlackShoe 2020-12-02          504      NaN
# 136     HDLT_Test_Static_Cricket 2020-12-02          954      NaN
# 12    HDLT_Test_Static_WhiteShoe 2020-12-02        21780     24.0
# 32   HDLT_Test_Animated_ShoeSpin 2020-12-02        17348     14.0
# 134   HDLT_Test_Static_BlackShoe 2020-12-03          373      NaN
# 21    HDLT_Test_Static_WhiteShoe 2020-12-03        23856     28.0
# 29   HDLT_Test_Animated_ShoeSpin 2020-12-03        13713     15.0
# 102     HDLT_Test_Static_Cricket 2020-12-03         1264      2.0
# 11   HDLT_Test_Animated_ShoeSpin 2020-12-04        19477     17.0
# 34    HDLT_Test_Static_WhiteShoe 2020-12-04        15154     13.0
# 138     HDLT_Test_Static_Cricket 2020-12-04          748      NaN
# 125   HDLT_Test_Static_BlackShoe 2020-12-04          653      1.0
# 36   HDLT_Test_Animated_ShoeSpin 2020-12-05        10802     11.0
# 156     HDLT_Test_Static_Cricket 2020-12-05          354      1.0
# 6     HDLT_Test_Static_WhiteShoe 2020-12-05        26917     35.0
# 111   HDLT_Test_Static_BlackShoe 2020-12-05          905      3.0
# 119   HDLT_Test_Static_BlackShoe 2020-12-06          571      NaN
# 57   HDLT_Test_Animated_ShoeSpin 2020-12-06         4951      2.0
# 147     HDLT_Test_Static_Cricket 2020-12-06          313      NaN
# 0     HDLT_Test_Static_WhiteShoe 2020-12-06        34584     24.0
# 61   HDLT_Test_Animated_ShoeSpin 2020-12-07         6270      8.0
# 4     HDLT_Test_Static_WhiteShoe 2020-12-07        31713     26.0
# 129   HDLT_Test_Static_BlackShoe 2020-12-07          855      1.0
# 157     HDLT_Test_Static_Cricket 2020-12-07          395      NaN
#
#      Amount Spent (USD)  Purchase  Signup  Link Clicks  \
# 24             269.0864       7.0     9.0        134.0
# 35             360.8472       9.0    15.0         87.0
# 146             16.0217       NaN     NaN          2.0
# 107            199.5539       NaN     1.0         10.0
# 141              8.3093       NaN     NaN          4.0
# 136             69.8290       NaN     NaN          4.0
# 12             401.9402      16.0    24.0        151.0
# 32             263.4513       7.0    14.0        101.0
# 134              8.3929       NaN     NaN          4.0
# 21             436.5266      15.0    28.0        137.0
# 29             215.5771       9.0    15.0        120.0
# 102             80.5070       NaN     2.0         11.0
# 11             360.5129       9.0    17.0        152.0
# 34             292.9160       7.0    13.0         98.0
# 138             51.3536       NaN     NaN          4.0
# 125             14.4697       NaN     1.0          5.0
# 36             214.6578       7.0    11.0         86.0
# 156             21.8526       NaN     1.0          NaN
# 6              475.7214      21.0    35.0        176.0
# 111             19.4481       1.0     3.0          8.0
# 119             11.1149       NaN     NaN          6.0
# 57              87.9166       NaN     2.0         39.0
# 147             19.3693       NaN     NaN          2.0
# 0              575.2901      14.0    24.0        194.0
# 61             103.9144       2.0     8.0         34.0
# 4              572.4368      10.0    26.0        178.0
# 129             15.9262       NaN     1.0          5.0
# 157             20.4123       NaN     NaN          NaN
#
#                          Status reasons
# 24   campaign paused; limited by budget
# 35   campaign paused; limited by budget
# 146                                indc
# 107                                  na
# 141                        status check
# 136                                indc
# 12   campaign paused; limited by budget
# 32                         status check
# 134  campaign paused; limited by budget
# 21                    limited by budget
# 29                    limited by budget
# 102  campaign paused; limited by budget
# 11                    limited by budget
# 34                    limited by budget
# 138                   limited by budget
# 125                              active
# 36                    limited by budget
# 156                   limited by budget
# 6    campaign paused; limited by budget
# 111  campaign paused; limited by budget
# 119  campaign paused; limited by budget
# 57                    limited by budget
# 147                   limited by budget
# 0                                active
# 61   campaign paused; limited by budget
# 4                     limited by budget
# 129                                  na
# 157                   limited by budget

# %%
Cost = seven_days["Amount Spent (USD)"].sum()
Cost
# Out:
# 5187.355300000001

# %%
Impression = seven_days["Impressions"].sum()
Impression
# Out:
# 270492

# %%
Cost_per_impression = Cost/Impression
Cost_per_impression
# Out:
# 0.01917748140425595

# %%
CPM = Cost_per_impression*1000
CPM
# Out:
# 19.17748140425595

# %%
##Question 4

# %%
Groups = file_df.groupby("Ad Set Name").sum()
Groups
# Out:
#                                     Impressions   Results  Amount Spent (USD)  \
# Ad Set Name
# ALL_Retargeting_Signup No Purchase         7157    6758.0            263.1170
# ALL_Retargeting_Site Visitors            260817  256792.0            270.9965
# US_Interest_Basketball                   287266     209.0           4384.5710
# US_Lookalike_RecentPurchases             399350     312.0           6277.1776
# WW_Interest_Cricket                        6191       4.0            462.9274
# WW_Lookalike_RecentPurchases             556830     520.0          10361.9675
#
#                                     Purchase  Signup  Link Clicks
# Ad Set Name
# ALL_Retargeting_Signup No Purchase       0.0     0.0         17.0
# ALL_Retargeting_Site Visitors            0.0     0.0         62.0
# US_Interest_Basketball                 135.0   209.0       1598.0
# US_Lookalike_RecentPurchases           203.0   312.0       2331.0
# WW_Interest_Cricket                      0.0     4.0         31.0
# WW_Lookalike_RecentPurchases           307.0   520.0       3704.0

# %%
CTR = Groups["Link Clicks"]/Groups["Impressions"]
CTR.sort_values()
# Out:
# Ad Set Name
# ALL_Retargeting_Site Visitors         0.000238
# ALL_Retargeting_Signup No Purchase    0.002375
# WW_Interest_Cricket                   0.005007
# US_Interest_Basketball                0.005563
# US_Lookalike_RecentPurchases          0.005837
# WW_Lookalike_RecentPurchases          0.006652
# dtype: float64

# %%
##Question 6

# %%
import matplotlib

# %%
Later_days = file_df.loc[(file_df["Day"] >="2020-12-08")
                        & (file_df["Day"] <= "2020-12-31")]
Later_days.sort_values(by=["Day"]).head(5)
# Out:
#                             Campaign Name                   Ad Set Name  \
# 105  Prospecting -- Signups and Purchases  US_Lookalike_RecentPurchases
# 86   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
# 65   Prospecting -- Signups and Purchases  US_Lookalike_RecentPurchases
# 10   Prospecting -- Signups and Purchases  US_Lookalike_RecentPurchases
# 49   Prospecting -- Signups and Purchases  WW_Lookalike_RecentPurchases
#
#                          Ad Name        Day  Impressions  Results  \
# 105   HDLT_Test_Static_BlackShoe 2020-12-08         1648      NaN
# 86   HDLT_Test_Animated_ShoeSpin 2020-12-08         1811      1.0
# 65    HDLT_Test_Static_WhiteShoe 2020-12-08         4663      1.0
# 10   HDLT_Test_Animated_ShoeSpin 2020-12-08        28143     23.0
# 49    HDLT_Test_Static_WhiteShoe 2020-12-08        10677      9.0
#
#      Amount Spent (USD)  Purchase  Signup  Link Clicks     Status reasons
# 105             23.7938       NaN     NaN         11.0                 na
# 86              27.8888       1.0     1.0         17.0             active
# 65              52.9004       1.0     1.0         29.0  limited by budget
# 10             382.0384      11.0    23.0        152.0             active
# 49             199.6031       2.0     9.0         59.0               indc

# %%
Later_days["CTR"] = Later_days["Link Clicks"]/Later_days["Impressions"]
Later_days["CTR"]
# Out:
# <ipython-input-111-c4721bd00d33>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Later_days["CTR"] = Later_days["Link Clicks"]/Later_days["Impressions"]
# 1      0.005937
# 2      0.005609
# 3      0.005927
# 5      0.004902
# 7      0.006348
#          ...
# 154         NaN
# 155         NaN
# 158         NaN
# 159         NaN
# CTR         NaN
# Name: CTR, Length: 133, dtype: float64

# %%
Later_days.head(5)
# Out:
#                           Campaign Name             Ad Set Name  \
# 1  Prospecting -- Signups and Purchases  US_Interest_Basketball
# 2  Prospecting -- Signups and Purchases  US_Interest_Basketball
# 3  Prospecting -- Signups and Purchases  US_Interest_Basketball
# 5  Prospecting -- Signups and Purchases  US_Interest_Basketball
# 7  Prospecting -- Signups and Purchases  US_Interest_Basketball
#
#                          Ad Name        Day  Impressions  Results  \
# 1  HDLT_Test_Animated_Basketball 2020-12-23      31495.0     23.0
# 2  HDLT_Test_Animated_Basketball 2020-12-25      32807.0     22.0
# 3  HDLT_Test_Animated_Basketball 2020-12-26      30201.0     23.0
# 5  HDLT_Test_Animated_Basketball 2020-12-22      36312.0     18.0
# 7  HDLT_Test_Animated_Basketball 2020-12-27      26309.0     28.0
#
#    Amount Spent (USD)  Purchase  Signup  Link Clicks     Status reasons  \
# 1            494.6203      14.0    23.0        187.0             active
# 2            405.1159       9.0    22.0        184.0             active
# 3            402.2864      14.0    23.0        179.0             active
# 5            649.4175      10.0    18.0        178.0  limited by budget
# 7            394.8247      19.0    28.0        167.0               indc
#
#         CTR
# 1  0.005937
# 2  0.005609
# 3  0.005927
# 5  0.004902
# 7  0.006348

# %%
import matplotlib.pyplot as plt

# %%
Later_days.plot(x="Day", y=, kind="bar", figsize=(9,8))




World_wide = file_df[(file_df["Ad Set Name"] == "WW_Lookalike_RecentPurchases") | (file_df["Ad Set Name"] == "WW_Interest_Cricket")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-1ba51ae39c24> in <module>
# ----> 1 Later_days.plot(x="Day", y=["Ad Set Name"], kind="bar", figsize=(9,8))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     276     def generate(self):
#     277         self._args_adjust()
# --> 278         self._compute_plot_data()
#     279         self._setup_subplots()
#     280         self._make_plot()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     439         # no non-numeric frames or series allowed
#     440         if is_empty:
# --> 441             raise TypeError("no numeric data to plot")
#     442
#     443         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
##Question 7 Animated vs. Static
#Static
Ads_Static = file_df[(file_df["Ad Name"].str.contains("Static"))]
Ads_Static_Sum
# Out:
# 2.970246116970277

# %%
#Animated
Ads_Animated = file_df[(file_df["Ad Name"].str.contains("Animated"))]
Ads_Animated_Sum = Ads_Animated["Amount Spent (USD)"].sum()/Ads_Animated["Link Clicks"].sum()
Ads_Animated_Sum
# Out:
# 2.688587298787211

# %%
Ads_perf["CPP"] = Ads_perf["Amount Spent (USD)"]/Ads_perf["Link Clicks"]

# %%
Ads_perf.sort_values("CPP")
# Out:
#                                Impressions   Results  Amount Spent (USD)  \
# Ad Name
# HDLT_Test_Static_BlackShoe           33136      31.0            679.2284
# HDLT_Test_Animated_ShoeSpin         475507     380.0           7808.1724
# HDLT_Test_Animated_Basketball       287266     209.0           4384.5710
# HDLT_Test_Static_WhiteShoe          447537     421.0           8151.7443
# Retargeting Ad                      267974  263550.0            534.1135
# HDLT_Test_Static_Cricket              6191       4.0            462.9274
#
#                                Purchase  Signup  Link Clicks        CPP
# Ad Name
# HDLT_Test_Static_BlackShoe         15.0    31.0        257.0   2.642912
# HDLT_Test_Animated_ShoeSpin       225.0   380.0       2937.0   2.658554
# HDLT_Test_Animated_Basketball     135.0   209.0       1598.0   2.743787
# HDLT_Test_Static_WhiteShoe        270.0   421.0       2841.0   2.869322
# Retargeting Ad                      0.0     0.0         79.0   6.760930
# HDLT_Test_Static_Cricket            0.0     4.0         31.0  14.933142

# %%
##Question 8 Day with the lowest cost per signup
Group_Day = file_df.groupby("Day").sum()
Group_Day.head(5)
# Out:
#             Impressions  Results  Amount Spent (USD)  Purchase  Signup  \
# Day
# 2020-12-01        36038     25.0            845.5092      16.0    25.0
# 2020-12-02        40586     38.0            743.5298      23.0    38.0
# 2020-12-03        39206     45.0            741.0036      24.0    45.0
# 2020-12-04        36032     31.0            719.2522      16.0    31.0
# 2020-12-05        38978     50.0            731.6799      29.0    50.0
#
#             Link Clicks
# Day
# 2020-12-01        233.0
# 2020-12-02        260.0
# 2020-12-03        272.0
# 2020-12-04        259.0
# 2020-12-05        270.0

# %%
Group_Day["CPS"] = Group_Day["Amount Spent (USD)"]/Group_Day["Signup"]
Group_Day.sort_values("CPS")
# Out:
#             Impressions   Results  Amount Spent (USD)  Purchase  Signup  \
# Day
# 2020-12-05        38978      50.0            731.6799      29.0    50.0
# 2020-12-19        37979      43.0            704.1805      27.0    43.0
# 2020-12-27        41129      41.0            674.4052      28.0    41.0
# 2020-12-03        39206      45.0            741.0036      24.0    45.0
# 2020-12-25        49076      40.0            690.7732      23.0    40.0
# 2020-12-24        42485      38.0            661.5712      24.0    38.0
# 2020-12-26        46589      39.0            686.8692      25.0    39.0
# 2020-12-16        44198      39.0            695.7038      24.0    39.0
# 2020-12-14        41528      36.0            689.1734      21.0    36.0
# 2020-12-21        30679      25.0            481.2013      16.0    25.0
# 2020-12-20        44150      36.0            693.2445      31.0    36.0
# 2020-12-18        38741      36.0            694.2831      22.0    36.0
# 2020-12-23        38793      33.0            640.9171      22.0    33.0
# 2020-12-02        40586      38.0            743.5298      23.0    38.0
# 2020-12-07        39233      35.0            712.6897      12.0    35.0
# 2020-12-08        47281      34.0            693.3777      15.0    34.0
# 2020-12-13        42102      33.0            694.1757      23.0    33.0
# 2020-12-09        40118      32.0            675.0022      16.0    32.0
# 2020-12-17        44893      32.0            680.4820      18.0    32.0
# 2020-12-28        40136      31.0            676.9243      20.0    31.0
# 2020-12-04        36032      31.0            719.2522      16.0    31.0
# 2020-12-12        39563      31.0            724.6434      22.0    31.0
# 2020-12-11        38537      29.0            688.7674      18.0    29.0
# 2020-12-15        41249      29.0            689.1136      16.0    29.0
# 2020-12-29        68869   31112.0            743.3870      24.0    31.0
# 2020-12-06        40419      26.0            693.6909      14.0    26.0
# 2020-12-10        39210      24.0            689.1973      16.0    24.0
# 2020-12-31       159403  120556.0            913.4657      23.0    30.0
# 2020-12-22        39643      23.0            712.7523      15.0    23.0
# 2020-12-30       150768  111973.0            939.7906      22.0    30.0
# 2020-12-01        36038      25.0            845.5092      16.0    25.0
#
#             Link Clicks        CPS
# Day
# 2020-12-05        270.0  14.633598
# 2020-12-19        274.0  16.376291
# 2020-12-27        272.0  16.448907
# 2020-12-03        272.0  16.466747
# 2020-12-25        308.0  17.269330
# 2020-12-24        251.0  17.409768
# 2020-12-26        295.0  17.612031
# 2020-12-16        250.0  17.838559
# 2020-12-14        229.0  19.143706
# 2020-12-21        193.0  19.248052
# 2020-12-20        286.0  19.256792
# 2020-12-18        263.0  19.285642
# 2020-12-23        245.0  19.421730
# 2020-12-02        260.0  19.566574
# 2020-12-07        217.0  20.362563
# 2020-12-08        271.0  20.393462
# 2020-12-13        257.0  21.035627
# 2020-12-09        216.0  21.093819
# 2020-12-17        250.0  21.265062
# 2020-12-28        217.0  21.836268
# 2020-12-04        259.0  23.201684
# 2020-12-12        248.0  23.375594
# 2020-12-11        242.0  23.750600
# 2020-12-15        228.0  23.762538
# 2020-12-29        222.0  23.980226
# 2020-12-06        241.0  26.680419
# 2020-12-10        226.0  28.716554
# 2020-12-31        284.0  30.448857
# 2020-12-22        216.0  30.989230
# 2020-12-30        248.0  31.326353
# 2020-12-01        233.0  33.820368
